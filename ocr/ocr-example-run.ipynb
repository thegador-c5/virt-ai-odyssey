# %% [markdown]
# See the following link for more detailed documentation:
# https://blog.roboflow.com/how-to-use-easyocr/
#
# EasyOCR is a Python package for detecting and extracting text from images such as photos or scanned documents.
#
# To get started, install all the necessary libraries required. We will be installing the PyTorch library (which is a core dependency) and the EasyOCR library, using the ‘pip’ package installer.

# %%
pip install torch torchvision torchaudio easyocr
# Out:
# Requirement already satisfied: torch in /opt/app-root/lib64/python3.11/site-packages (2.2.2+cpu)
# Requirement already satisfied: torchvision in /opt/app-root/lib64/python3.11/site-packages (0.17.2+cpu)
# Requirement already satisfied: torchaudio in /opt/app-root/lib64/python3.11/site-packages (2.2.2)
# Requirement already satisfied: easyocr in /opt/app-root/lib64/python3.11/site-packages (1.7.2)
# Requirement already satisfied: filelock in /opt/app-root/lib64/python3.11/site-packages (from torch) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/app-root/lib64/python3.11/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /opt/app-root/lib64/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/app-root/lib64/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/app-root/lib64/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/app-root/lib64/python3.11/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in /opt/app-root/lib64/python3.11/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/app-root/lib64/python3.11/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: opencv-python-headless in /opt/app-root/lib64/python3.11/site-packages (from easyocr) (4.9.0.80)
# Requirement already satisfied: scipy in /opt/app-root/lib64/python3.11/site-packages (from easyocr) (1.12.0)
# Requirement already satisfied: scikit-image in /opt/app-root/lib64/python3.11/site-packages (from easyocr) (0.24.0)
# Requirement already satisfied: python-bidi in /opt/app-root/lib64/python3.11/site-packages (from easyocr) (0.6.3)
# Requirement already satisfied: PyYAML in /opt/app-root/lib64/python3.11/site-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in /opt/app-root/lib64/python3.11/site-packages (from easyocr) (2.0.6)
# Requirement already satisfied: pyclipper in /opt/app-root/lib64/python3.11/site-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in /opt/app-root/lib64/python3.11/site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib64/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: imageio>=2.33 in /opt/app-root/lib64/python3.11/site-packages (from scikit-image->easyocr) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/app-root/lib64/python3.11/site-packages (from scikit-image->easyocr) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /opt/app-root/lib64/python3.11/site-packages (from scikit-image->easyocr) (23.2)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/app-root/lib64/python3.11/site-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: mpmath>=0.19 in /opt/app-root/lib64/python3.11/site-packages (from sympy->torch) (1.3.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Setup to display images by importing the Image package

# %%
from PIL import Image

# %% [markdown]
# Ensure that we know what the current working directory is and change if necessary to find the necessary resources for this example.

# %%
import os

# %%
dir = os.getcwd()

# %%
print(dir)
# Out:
# /opt/app-root/src/parasol-insurance/lab-materials/ocr

# %%
os.chdir("/opt/app-root/src/parasol-insurance/lab-materials/ocr")

# %%
print(os.getcwd())
# Out:
# /opt/app-root/src/parasol-insurance/lab-materials/ocr

# %% [markdown]
# Import the EasyOCR package and initialize its ‘reader’ function. We can also select the language we want to detect and extract. There are over 80 languages to choose from. For this example, let’s choose English as ‘en.’

# %%
import easyocr

# %%
reader = easyocr.Reader(['en'],model_storage_directory='/opt/app-root/src/parasol-insurance/lab-materials/ocr/models')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
result = reader.readtext('/opt/app-root/src/parasol-insurance/lab-materials/ocr/images/ocr-image-1.jpg',detail=0)

# %%
# Display the image
Image.open("images/ocr-image-1.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x649>

# %%
# Print the text found in the image
print(result)
# Out:
# ['45Vatitecentre', 'umatoopU Euu TeuigeeVTii', 'CHILDDN', "'EREZJ LDULT", '~VVRIDER E3.30', 'HyuuhLuc O', '132', 'citybus', 'VIEZT', 'M32 HOD', 'Taav', 'NZCSTzR', 'Jelt']

# %%
result = reader.readtext('/opt/app-root/src/parasol-insurance/lab-materials/ocr/images/ocr-image-2.jpg',detail=0)

# %%
# Display the image
Image.open("images/ocr-image-2.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x744>

# %%
print(result)
# Out:
# []

# %%
result = reader.readtext('/opt/app-root/src/parasol-insurance/lab-materials/ocr/images/ocr-image-3.jpg',detail=0)

# %%
# Display the image
Image.open("images/ocr-image-3.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x307>

# %%
print(result)
# Out:
# ['532h']

# %%
result = reader.readtext('/opt/app-root/src/parasol-insurance/lab-materials/ocr/images/License-plate-1.jpg',detail=0)

# %%
# Display the image
Image.open("images/License-plate-1.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=728x671>

# %%
print(result)
# Out:
# ['U(', 'J(I', 'Ay34785']

# %%
result = reader.readtext('/opt/app-root/src/parasol-insurance/lab-materials/ocr/images/License-plate-2.jpg',detail=0)

# %%
# Display the image
Image.open("images/License-plate-2.jpg")

# %%
print(result)
